# %% [markdown]
# # Entrainement des modèles de ML
#
# * __Description__: Notebook pour entrainer les modèles de ML
# * __Source__: Fichiers csv
# * __Output__: Modèle ML
# * __Auteur__: Thomas GOBIN et Camille MATTHIEU
# * __Date de création__: 16/09/2022
# * __Date de mise à jour__: 16/09/2022

# %% [markdown]
# ## Import des outils

# %%
# %run /notebook/Scoring/train.ipynb
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## Lancement de la création des modèles

# %%
create_model()
# Out:
# Training... global
# Training model
#   (0, 44705)	0.36289584970993793
#   (0, 2283)	0.440325366450951
#   (0, 30410)	0.5336935508184941
#   (0, 7613)	0.6241725464468021
#   (1, 43516)	0.1387688235979541
#   (1, 27656)	0.1649830843691975
#   (1, 20098)	0.13214383810131797
#   (1, 3868)	0.17470884303016526
#   (1, 7386)	0.17542315636991013
#   (1, 36494)	0.2961688510769325
#   (1, 8339)	0.12749141518839283
#   (1, 27619)	0.14706335127957648
#   (1, 10196)	0.21296848707675237
#   (1, 36962)	0.18394628421681952
#   (1, 1773)	0.15941792709810976
#   (1, 187)	0.2961688510769325
#   (1, 32128)	0.12418624313252578
#   (1, 2493)	0.25257142014241024
#   (1, 28474)	0.09151631924532874
#   (1, 15410)	0.21091151575527856
#   (1, 31863)	0.28788782180139866
#   (1, 1996)	0.22089631743689897
#   (1, 35390)	0.1521285029955299
#   (1, 10195)	0.17600765057245668
#   (1, 16231)	0.11105618720474761
#   :	:
#   (32448, 39096)	0.22160012067518595
#   (32448, 35312)	0.19118352122728688
# ...
